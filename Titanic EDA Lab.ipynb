# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# ...
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Length: 891, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# dtype: int64

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# dtype: int64

# %%
df.Name.value_counts()
# Out:
# Graham, Mr. George Edward                              1
# Elias, Mr. Tannous                                     1
# Madill, Miss. Georgette Alexandra                      1
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    1
# Beane, Mrs. Edward (Ethel Clarke)                      1
# Roebling, Mr. Washington Augustus II                   1
# Moran, Mr. James                                       1
# Padro y Manent, Mr. Julian                             1
# Scanlan, Mr. James                                     1
# Ali, Mr. William                                       1
# Weisz, Mrs. Leopold (Mathilde Francoise Pede)          1
# Abbing, Mr. Anthony                                    1
# Lahtinen, Mrs. William (Anna Sylfven)                  1
# Frost, Mr. Anthony Wood "Archie"                       1
# Lang, Mr. Fang                                         1
# ...
# McEvoy, Mr. Michael                                  1
# ...

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# dtype: int64

# %%
df.Age.value_counts()
# Out:
# 24    30
# 22    27
# 18    26
# 28    25
# 30    25
# 19    25
# 21    24
# 25    23
# 36    22
# 29    20
# 32    18
# 35    18
# 27    18
# 26    18
# 16    17
# ...
# 53.00    1
# 70.50    1
# 14.50    1
# 0.92     1
# 74.00    1
# 36.50    1
# 80.00    1
# 12.00    1
# 55.50    1
# 34.50    1
# 24.50    1
# 66.00    1
# 23.50    1
# 0.67     1
# 20.50    1
# Length: 88, dtype: int64

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# dtype: int64

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# dtype: int64

# %%
df.Ticket.value_counts()
# Out:
# CA. 2343        7
# 347082          7
# 1601            7
# 347088          6
# CA 2144         6
# 3101295         6
# 382652          5
# S.O.C. 14879    5
# PC 17757        4
# 4133            4
# LINE            4
# 349909          4
# 347077          4
# W./C. 6608      4
# 113760          4
# ...
# STON/O 2. 3101273    1
# 345777               1
# STON/O 2. 3101274    1
# STON/O 2. 3101275    1
# 113794               1
# 2649                 1
# 374887               1
# 349213               1
# 349210               1
# 349242               1
# 349216               1
# 112052               1
# 315088               1
# 349215               1
# W./C. 14258          1
# Length: 681, dtype: int64

# %%
df.Fare.value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
# 10.5000    24
# 7.9250     18
# 7.7750     16
# 7.2292     15
# 26.5500    15
# 0.0000     15
# 7.2500     13
# 7.8542     13
# 8.6625     13
# 7.2250     12
# ...
# 15.0000    1
# 28.7125    1
# 61.1750    1
# 6.2375     1
# 15.1000    1
# 39.4000    1
# 81.8583    1
# 61.9792    1
# 7.8000     1
# 22.0250    1
# 47.1000    1
# 13.4167    1
# 14.1083    1
# 15.5500    1
# 13.7917    1
# Length: 248, dtype: int64

# %%
df.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# D                  3
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# B57 B59 B63 B66    2
# C68                2
# B58 B60            2
# E121               2
# D20                2
# E8                 2
# E44                2
# ...
# E50    1
# A14    1
# C91    1
# A16    1
# B38    1
# B39    1
# C95    1
# B78    1
# B79    1
# C99    1
# B37    1
# A19    1
# E12    1
# A7     1
# D15    1
# Length: 147, dtype: int64

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# dtype: int64

# %%
df.PassengerId.value_counts().plot(kind='bar')

# %%
df.Survived.value_counts().plot(kind='bar')

# %%
df.Pclass.value_counts().plot(kind='bar')

# %%
df.Name.value_counts().plot(kind='bar')

# %%
df.Sex.value_counts().plot(kind='bar')

# %%
df.Age.value_counts().plot(kind='bar')

# %%
df.SibSp.value_counts().plot(kind='bar')

# %%
df.Parch.value_counts().plot(kind='bar')

# %%
df.Ticket.value_counts().plot(kind='bar')

# %%
df.Fare.value_counts().plot(kind='bar')

# %%
df.Cabin.value_counts().plot(kind='bar')

# %%
df.Embarked.value_counts().plot(kind='bar')

# %%
df[df.Sex=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %%
df[df.Survived==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
df[df.Survived==0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 24            25         0       3
# 26            27         0       3
# 27            28         0       1
# 29            30         0       3
# 30            31         0       1
# 33            34         0       2
# 34            35         0       1
# 35            36         0       1
# 37            38         0       3
# 38            39         0       3
# 40            41         0       3
# 41            42         0       2
# 42            43         0       3
# 45            46         0       3
# ...

# %%
df[df.Pclass==3]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 16            17         0       3
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 32            33         1       3
# 36            37         1       3
# 37            38         0       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# ...

# %%
df[df.Pclass==0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Pclass==2]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# 33            34         0       2
# 41            42         0       2
# 43            44         1       2
# 53            54         1       2
# 56            57         1       2
# 58            59         1       2
# 66            67         1       2
# 70            71         0       2
# 72            73         0       2
# 78            79         1       2
# 84            85         1       2
# 98            99         1       2
# 99           100         0       2
# 117          118         0       2
# 120          121         0       2
# 122          123         0       2
# 123          124         1       2
# 133          134         1       2
# 134          135         0       2
# 135          136         0       2
# ...

# %%
df[df.Name=='Richard, Mr. Emile']
# Out:
#      PassengerId  Survived  Pclass                Name   Sex  Age  SibSp  \
# 135          136         0       2  Richard, Mr. Emile  male   23      0
#
#      Parch         Ticket     Fare Cabin Embarked
# 135      0  SC/PARIS 2133  15.0458   NaN        C

# %%
df[df.Name=='Navratil, Mr. Michel ("Louis M Hoffman")']
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 148          149         0       2  Navratil, Mr. Michel ("Louis M Hoffman")
#
#       Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 148  male  36.5      0      2  230080    26    F2        S

# %%
df[df.Age<30]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 12            13         0       3
# 14            15         0       3
# 16            17         0       3
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 27            28         0       1
# 34            35         0       1
# 37            38         0       3
# 38            39         0       3
# 39            40         1       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 49            50         0       3
# 50            51         0       3
# 51            52         0       3
# 53            54         1       2
# 56            57         1       2
# ...

# %%
df[df.Age>45]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 52            53         1       1
# 54            55         0       1
# 92            93         0       1
# 94            95         0       3
# 96            97         0       1
# 110          111         0       1
# 116          117         0       3
# 124          125         0       1
# 132          133         0       3
# 150          151         0       2
# 152          153         0       3
# 155          156         0       1
# 170          171         0       1
# 174          175         0       1
# 177          178         0       1
# 195          196         1       1
# 203          204         0       3
# 222          223         0       3
# 232          233         0       2
# 249          250         0       2
# 252          253         0       1
# ...

# %%
df[df.Age>65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
df[df.Age<50]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 30            31         0       1
# 34            35         0       1
# 35            36         0       1
# 37            38         0       3
# ...

# %%
df[df.SibSp==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 9             10         1       2
# 10            11         1       3
# 13            14         0       3
# 18            19         0       3
# 25            26         1       3
# 31            32         1       1
# 34            35         0       1
# 35            36         0       1
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 46            47         0       3
# 49            50         0       3
# 52            53         1       1
# 53            54         1       2
# 58            59         1       2
# 62            63         0       1
# 65            66         1       3
# 73            74         0       3
# 86            87         0       3
# 92            93         0       1
# ...

# %%
df[df.SibSp==0]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 8              9         1       3
# 11            12         1       1
# 12            13         0       3
# 14            15         0       3
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# 36            37         1       3
# 37            38         0       3
# 42            43         0       3
# 44            45         1       3
# ...

# %%
df[df.SibSp==3]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 24            25         0       3
# 27            28         0       1
# 63            64         0       3
# 85            86         1       3
# 88            89         1       1
# 176          177         0       3
# 229          230         0       3
# 341          342         1       1
# 374          375         0       3
# 409          410         0       3
# 485          486         0       3
# 634          635         0       3
# 642          643         0       3
# 726          727         1       2
# 819          820         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 7                       Palsson, Master. Gosta Leonard    male    2      3
# 24                       Palsson, Miss. Torborg Danira  female    8      3
# 27                      Fortune, Mr. Charles Alexander    male   19      3
# ...

# %%
df[df.SibSp==2]
# Out:
#      PassengerId  Survived  Pclass  \
# 38            39         0       3
# 48            49         0       3
# 69            70         0       3
# 104          105         0       3
# 120          121         0       2
# 147          148         0       3
# 183          184         1       2
# 245          246         0       1
# 301          302         1       3
# 311          312         1       1
# 330          331         1       3
# 333          334         0       3
# 392          393         0       3
# 436          437         0       3
# 437          438         1       2
# 448          449         1       3
# 469          470         1       3
# 529          530         0       2
# 565          566         0       3
# 571          572         1       1
# 600          601         1       2
# 618          619         1       2
# 644          645         1       3
# 655          656         0       2
# 660          661         1       1
# ...

# %%
df[df.Parch==2]
# Out:
#      PassengerId  Survived  Pclass  \
# 8              9         1       3
# 27            28         0       1
# 43            44         1       2
# 58            59         1       2
# 59            60         0       3
# 63            64         0       3
# 68            69         1       3
# 71            72         0       3
# 78            79         1       2
# 88            89         1       1
# 93            94         0       3
# 119          120         0       3
# 136          137         1       1
# 140          141         0       3
# 147          148         0       3
# 148          149         0       2
# 153          154         0       3
# 159          160         0       3
# 165          166         1       3
# 180          181         0       3
# 182          183         0       3
# 184          185         1       3
# 201          202         0       3
# 233          234         1       3
# 237          238         1       2
# ...

# %%
df[df.Parch==0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# 12            13         0       3
# 14            15         0       3
# 15            16         1       2
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 31            32         1       1
# 32            33         1       3
# ...

# %%
df[df.Parch==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 10            11         1       3
# 16            17         0       3
# 24            25         0       3
# 50            51         0       3
# 54            55         0       1
# 65            66         1       3
# 97            98         1       1
# 98            99         1       2
# 102          103         0       1
# 118          119         0       1
# 124          125         0       1
# 128          129         1       3
# 145          146         0       2
# 155          156         0       1
# 160          161         0       3
# 164          165         0       3
# 166          167         1       1
# 171          172         0       3
# 172          173         1       3
# 175          176         0       3
# 176          177         0       3
# 183          184         1       2
# 188          189         0       3
# 193          194         1       2
# ...

# %%
df[df.Ticket==349256]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Ticket=='PP 9549']
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 394          395         1       3
#
#                                                   Name     Sex  Age  SibSp  \
# 10                     Sandstrom, Miss. Marguerite Rut  female    4      1
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female   24      0
#
#      Parch   Ticket  Fare Cabin Embarked
# 10       1  PP 9549  16.7    G6        S
# 394      2  PP 9549  16.7    G6        S

# %%
df[df.Ticket=='A./5. 2152']
# Out:
#     PassengerId  Survived  Pclass                      Name   Sex  Age  SibSp  \
# 37           38         0       3  Cann, Mr. Ernest Charles  male   21      0
#
#     Parch      Ticket  Fare Cabin Embarked
# 37      0  A./5. 2152  8.05   NaN        S

# %%
df[df.Fare==21.0750]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 24            25         0       3
# 374          375         0       3
# 567          568         0       3
#
#                                             Name     Sex  Age  SibSp  Parch  \
# 7                 Palsson, Master. Gosta Leonard    male    2      3      1
# 24                 Palsson, Miss. Torborg Danira  female    8      3      1
# 374                   Palsson, Miss. Stina Viola  female    3      3      1
# 567  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female   29      0      4
#
#      Ticket    Fare Cabin Embarked
# 7    349909  21.075   NaN        S
# 24   349909  21.075   NaN        S
# 374  349909  21.075   NaN        S
# 567  349909  21.075   NaN        S

# %%
df[df.Fare==15.2458]
# Out:
#      PassengerId  Survived  Pclass  \
# 65            66         1       3
# 140          141         0       3
# 255          256         1       3
# 709          710         1       3
# 852          853         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 65                            Moubarek, Master. Gerios    male  NaN      1
# 140                      Boulos, Mrs. Joseph (Sultana)  female  NaN      0
# 255            Touma, Mrs. Darwis (Hanne Youssef Razi)  female   29      0
# 709  Moubarek, Master. Halim Gonios ("William George")    male  NaN      1
# 852                            Boulos, Miss. Nourelain  female    9      1
#
#      Parch Ticket     Fare Cabin Embarked
# 65       1   2661  15.2458   NaN        C
# 140      2   2678  15.2458   NaN        C
# 255      2   2650  15.2458   NaN        C
# 709      1   2661  15.2458   NaN        C
# 852      1   2678  15.2458   NaN        C

# %%
df[df.Sex==82.1708]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Fare==82.1708]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 34            35         0       1                Meyer, Mr. Edgar Joseph
# 375          376         1       1  Meyer, Mrs. Edgar Joseph (Leila Saks)
#
#         Sex  Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 34     male   28      1      0  PC 17604  82.1708   NaN        C
# 375  female  NaN      1      0  PC 17604  82.1708   NaN        C

# %%
df[df.Cabin=='NaN']
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Cabin=='D26']
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex  Age  \
# 102          103         0       1    White, Mr. Richard Frasar  male   21
# 124          125         0       1  White, Mr. Percival Wayland  male   54
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 102      0      1  35281  77.2875   D26        S
# 124      0      1  35281  77.2875   D26        S

# %%
df[df.Embarked=='C']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# 31            32         1       1
# 34            35         0       1
# 36            37         1       3
# 39            40         1       3
# 42            43         0       3
# 43            44         1       2
# 48            49         0       3
# 52            53         1       1
# 54            55         0       1
# 57            58         0       3
# 60            61         0       3
# 64            65         0       1
# 65            66         1       3
# 73            74         0       3
# 96            97         0       1
# 97            98         1       1
# 111          112         0       3
# 114          115         0       3
# 118          119         0       1
# 122          123         0       2
# ...

# %%
df[df.Embarked=='S']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 17            18         1       2
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 29            30         0       3
# 33            34         0       2
# 35            36         0       1
# 37            38         0       3
# ...

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Name.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.PassengerId.hist()

# %%
df.Survived.hist()

# %%
df.Pclass.hist()

# %%
df.Name.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-877c71778a74> in <module>()
# ----> 1 df.Name.hist()
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2570         values = self.dropna().values
#    2571
# -> 2572         ax.hist(values, bins=bins, **kwds)
#    2573         ax.grid(grid)
#    2574         axes = np.array([ax])
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\matplotlib\axes\_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5634             # this will automatically overwrite bins,
#    5635             # so that each histogram uses the same bins
# ...

# %%
df.SibSp.hist()

# %%
df.Parch.hist()

# %%
df.Ticket.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-90c6c968dd10> in <module>()
# ----> 1 df.Ticket.hist()
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2570         values = self.dropna().values
#    2571
# -> 2572         ax.hist(values, bins=bins, **kwds)
#    2573         ax.grid(grid)
#    2574         axes = np.array([ax])
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\matplotlib\axes\_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5634             # this will automatically overwrite bins,
#    5635             # so that each histogram uses the same bins
# ...

# %%
df.Fare.hist()

# %%
df.Cabin.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-6e81786ba09e> in <module>()
# ----> 1 df.Cabin.hist()
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2570         values = self.dropna().values
#    2571
# -> 2572         ax.hist(values, bins=bins, **kwds)
#    2573         ax.grid(grid)
#    2574         axes = np.array([ax])
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\matplotlib\axes\_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5634             # this will automatically overwrite bins,
#    5635             # so that each histogram uses the same bins
# ...

# %%
df.Embarked.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-30755746ae79> in <module>()
# ----> 1 df.Embarked.hist()
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2570         values = self.dropna().values
#    2571
# -> 2572         ax.hist(values, bins=bins, **kwds)
#    2573         ax.grid(grid)
#    2574         axes = np.array([ax])
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\matplotlib\axes\_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5634             # this will automatically overwrite bins,
#    5635             # so that each histogram uses the same bins
# ...

# %%
df[df.Age>40].Survived.value_counts().plot(kind='barh')

# %%
df[df.Sex=='female'].Sex.value_counts().plot(kind='barh')

# %%
df[df.Embarked=='S'].Cabin.value_counts().plot(kind='barh')

# %%
df[df.SibSp==1].Survived.value_counts().plot(kind='barh')

# %%
df[df.PassengerId==2].Survived.value_counts().plot(kind='barh')

# %%
df[df.Age>10].Sex.value_counts().plot(kind='barh')

# %%
df[df.Fare==7.2500].Survived.value_counts().plot(kind='barh')

# %%
df[df.Ticket==347742].Survived.value_counts().plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-c02cae72425d> in <module>()
# ----> 1 df[df.Ticket==347742].Survived.value_counts().plot(kind='barh')
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    2258                      secondary_y=secondary_y, **kwds)
#    2259
# -> 2260     plot_obj.generate()
#    2261     plot_obj.draw()
#    2262
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in generate(self)
#     898     def generate(self):
#     899         self._args_adjust()
# --> 900         self._compute_plot_data()
#     901         self._setup_subplots()
#     902         self._make_plot()
#
# ...

# %%
df[df.Sex=='female'].Survived.value_counts().plot(kind='barh')

# %%
df[df.Parch==1].Sex.value_counts().plot(kind='barh')

# %%
df[df.Survived==1].Sex.value_counts().plot(kind='barh')

# %%
fig, axs=plt.subplots(1,2)
df[df.Sex=='female'].Age.value_counts().plot(kind='barh',ax=axs[0],title='female survived')
df[df.Sex=='male'].Age.value_counts().plot(kind='barh',ax=axs[1],title='male survived')

# %%
fig, axs=plt.subplots(1,2)
df[df.Age<80].Survived.value_counts().plot(kind='barh',ax=axs[0],title='Age<80')
df[df.Age>4].Survived.value_counts().plot(kind='barh',ax=axs[1],title='Age>4')

# %%
fig, axs=plt.subplots(1,2)
df[df.PassengerId==1].Survived.value_counts().plot(kind='barh',ax=axs[0],title='Passenger1 survived')
df[df.PassengerId==60].Survived.value_counts().plot(kind='barh',ax=axs[1],title='Passenger60 survived')

# %%
fig, axs=plt.subplots(1,2)
df[df.Age==NaN].Survived.value_counts().plot(kind='barh',ax=axs[0],title='survived')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-6c34c7c2eaf3> in <module>()
#       1 fig, axs=plt.subplots(1,2)
# ----> 2 df[df.Age==NaN].Survived.value_counts().plot(kind='barh',ax=axs[0],title='survived')
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    2258                      secondary_y=secondary_y, **kwds)
#    2259
# -> 2260     plot_obj.generate()
#    2261     plot_obj.draw()
#    2262
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in generate(self)
#     898     def generate(self):
#     899         self._args_adjust()
# --> 900         self._compute_plot_data()
#     901         self._setup_subplots()
#     902         self._make_plot()
#
# ...

# %%
fig, axs=plt.subplots(1,2)
df[df.Survived==1].Sex.value_counts().plot(kind='barh',ax=axs[0],title='survived')
df[df.Survived==0].Sex.value_counts().plot(kind='barh',ax=axs[1],title='not survived')

# %%
df[df.Age<80].Survived.value_counts().plot(kind='barh')

# %%
df[df.Sex=='female'].Survived.value_counts().plot(kind='barh')

# %%
df[df.Ticket==347742].Sex.value_counts().plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-517a6ebef62f> in <module>()
# ----> 1 df[df.Ticket==347742].Sex.value_counts().plot(kind='barh')
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    2258                      secondary_y=secondary_y, **kwds)
#    2259
# -> 2260     plot_obj.generate()
#    2261     plot_obj.draw()
#    2262
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in generate(self)
#     898     def generate(self):
#     899         self._args_adjust()
# --> 900         self._compute_plot_data()
#     901         self._setup_subplots()
#     902         self._make_plot()
#
# ...

# %%
df[df.Ticket==347742].Survived.value_counts().plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-c02cae72425d> in <module>()
# ----> 1 df[df.Ticket==347742].Survived.value_counts().plot(kind='barh')
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    2258                      secondary_y=secondary_y, **kwds)
#    2259
# -> 2260     plot_obj.generate()
#    2261     plot_obj.draw()
#    2262
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in generate(self)
#     898     def generate(self):
#     899         self._args_adjust()
# --> 900         self._compute_plot_data()
#     901         self._setup_subplots()
#     902         self._make_plot()
#
# ...

# %%
df[df.PassengerId==1].SibSp.value_counts().plot(kind='barh')

# %%
df[df.Parch==3].Survived.value_counts().plot(kind='barh')

# %%
df[df.Embarked=='C'].Sex.value_counts().plot(kind='barh')

# %%
df[df.Pclass==2].Parch.value_counts().plot(kind='barh')

# %%
df[(df.Parch==2) & (df.Age<30)].Sex.value_counts().plot(kind='barh')

# %%
df[(df.PassengerId<20) & (df.Sex=='Female')].Survived.value_counts().plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-513527cf5b63> in <module>()
# ----> 1 df[(df.PassengerId<20) & (df.Sex=='Female')].Survived.value_counts().plot(kind='barh')
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    2258                      secondary_y=secondary_y, **kwds)
#    2259
# -> 2260     plot_obj.generate()
#    2261     plot_obj.draw()
#    2262
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in generate(self)
#     898     def generate(self):
#     899         self._args_adjust()
# --> 900         self._compute_plot_data()
#     901         self._setup_subplots()
#     902         self._make_plot()
#
# ...

# %%
df[(df.Survived==0) & (df.Sex=='female')].Embarked.value_counts().plot(kind='barh')

# %%
df[(df.Survived==0) & (df.Sex=='male')].SibSp.value_counts().plot(kind='barh')

# %%
df[(df.Embarked=='S') & (df.Ticket==347742)].Survived.value_counts().plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-7656f4df4e01> in <module>()
# ----> 1 df[(df.Embarked=='S') & (df.Ticket==347742)].Survived.value_counts().plot(kind='barh')
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    2258                      secondary_y=secondary_y, **kwds)
#    2259
# -> 2260     plot_obj.generate()
#    2261     plot_obj.draw()
#    2262
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in generate(self)
#     898     def generate(self):
#     899         self._args_adjust()
# --> 900         self._compute_plot_data()
#     901         self._setup_subplots()
#     902         self._make_plot()
#
# ...

# %%
df[(df.Sex=='female') & (df.Cabin=='NaN')].Survived.value_counts().plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-69bc05b8bd2b> in <module>()
# ----> 1 df[(df.Sex=='female') & (df.Cabin=='NaN')].Survived.value_counts().plot(kind='barh')
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    2258                      secondary_y=secondary_y, **kwds)
#    2259
# -> 2260     plot_obj.generate()
#    2261     plot_obj.draw()
#    2262
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in generate(self)
#     898     def generate(self):
#     899         self._args_adjust()
# --> 900         self._compute_plot_data()
#     901         self._setup_subplots()
#     902         self._make_plot()
#
# ...

# %%
df[(df.Cabin=='NaN') & (df.PassengerId==95)].Survived.value_counts().plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-1254436d20e6> in <module>()
# ----> 1 df[(df.Cabin=='NaN') & (df.PassengerId==95)].Survived.value_counts().plot(kind='barh')
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    2258                      secondary_y=secondary_y, **kwds)
#    2259
# -> 2260     plot_obj.generate()
#    2261     plot_obj.draw()
#    2262
#
# C:\Users\AISHWARYA\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in generate(self)
#     898     def generate(self):
#     899         self._args_adjust()
# --> 900         self._compute_plot_data()
#     901         self._setup_subplots()
#     902         self._make_plot()
#
# ...
